# %% [markdown]
# <a href="https://colab.research.google.com/github/Utkarsh-Rane43/FODS-ASSIGNMENTS/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/iris - iris.csv')
df.head()
# Out:
#    x0   x1   x2   x3   x4         type
# 0   1  5.1  3.5  1.4  0.2  Iris-setosa
# 1   1  4.9  3.0  1.4  0.2  Iris-setosa
# 2   1  4.7  3.2  1.3  0.2  Iris-setosa
# 3   1  4.6  3.1  1.5  0.2  Iris-setosa
# 4   1  5.0  3.6  1.4  0.2  Iris-setosa
